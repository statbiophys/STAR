# %%
import os
import pandas as pd
from all_class.get_df import Get_df
from all_class.output_HC import Output
from all_class.v_nucl import V_nucl
from all_class.get_pgen import Get_pgen
from all_class.output_MC import Output_MC

# %% [markdown]
#  IMPORT THE DATASET

# %%
data_directory="data_test/"
data=pd.read_table(data_directory+"Test.tsv")

# %%
#IF YOU HAVE DIFFERENT NAMES FOR YOUR DATA RUN THIS CELL, FILLING IT WITH THE CURRENT NAMES
data.rename(columns={"Your V gene":"VGene",
                     "Your J gene":"JGene",
                    "Your nucleotide CDR3 sequences":"nSeqCDR3",
                    "Your amino acid CDR3 sequences":"nSeqCDR3"},inplace=True)

# %% [markdown]
# PRODUCE A DATAFRAME WITH ALL THE FEATURES

# %%
start = Get_df(data)
df_read = start.make()
mult_1, uniq_nucl = start.multiplicity()

# %% [markdown]
# OUTPUT OF FAST-STAR

# %%
threshold=0.000961 #inferred from min fdr of 5%
cluster_min=10 #min size to cluster the sequences

# %%
get_output = Output(df_read)
Binders = get_output.cluster(threshold,cluster_min)
df_read["fast-STAR"]=df_read.aaSeqCDR3.isin(Binders["aaSeqCDR3"])

# %% [markdown]
# TO COMPUTE PGEN (For one sequence or a column of DataFrame of sequences)

# %%
get_pgen = Get_pgen()
Pgen = get_pgen.compute_pgen("CARATAVVRGIINHFDYW") #To compute the Pgen of 1 seq
Pgen_parallel=get_pgen.apply_parallel(df_read["aaSeqCDR3"]) # " of a column of df using 10 CPU
df_read["Pgen"]=Pgen_parallel

# %% [markdown]
# OUTPUT OF FULL-STAR

# %%
output_MC=Output_MC(df_read)
output_MC.get_pvalue(uniq_nucl)
alpha=0.005 #value to set, %of estimated false positive 
Full_binders=output_MC.BH_procedure(uniq_nucl,alpha)
df_read["full-STAR"]=df_read.aaSeqCDR3.isin(Full_binders["aaSeqCDR3"])

# %%
df_read
# Out:
#             aaSeqCDR3  Frequency  Multiplicity  Neighbours   Nb_freq  \
# 0    CKSLLTTIPEKWFDPW      0.040            10          30  0.089820
# 1    CKCLLTTIPEKWFDPW      0.026             8          21  0.062874
# 2    CKSLLTTIPETWFDPW      0.004             2          20  0.059880
# 3    CKSLLTTIPENWFDPW      0.004             1          19  0.056886
# 4    CKSLLTTIPERWFDPW      0.006             3          18  0.053892
# ..                ...        ...           ...         ...       ...
# 287   CASDSSGYFDAFDIW      0.002             1           0  0.000000
# 288       CARGSSKFDRW      0.002             1           0  0.000000
# 289      CARAIAAADSYW      0.002             1           0  0.000000
# 290      CARGYSNGLDYW      0.002             1           0  0.000000
# 291    CARDVSIGVGADYW      0.002             1           0  0.000000
#
#      fast-STAR          Pgen  CDR3_len   Lambda_freq        Lambda  \
# 0        False  2.737826e-19        16  8.322990e-17  2.779879e-14
# 1        False  6.206779e-20        16  1.886861e-17  6.302115e-15
# 2        False  1.180772e-18        16  3.589546e-16  1.198908e-13
# 3        False  1.770759e-17        16  5.383107e-15  1.797958e-12
# 4        False  1.259666e-18        16  3.829385e-16  1.279015e-13
# ..         ...           ...       ...           ...           ...
# 287      False  2.478402e-10        15  7.063445e-08  2.359191e-05
# 288      False  7.972765e-14        11  1.666308e-11  5.565468e-09
# 289      False  2.677472e-10        12  6.104636e-08  2.038948e-05
# 290      False  2.979654e-10        12  6.793612e-08  2.269066e-05
# 291      False  3.613805e-13        14  9.612722e-11  3.210649e-08
#
#            Pvalue  full-STAR
# 0    3.335733e-54       True
# 1    3.391499e-35       True
# 2    3.562628e-33       True
# 3    3.564340e-31       True
# 4    3.387921e-29       True
# ..            ...        ...
# 287  1.000000e+00      False
# 288  1.000000e+00      False
# 289  1.000000e+00      False
# 290  1.000000e+00      False
# 291  1.000000e+00      False
#
# [292 rows x 12 columns]

# %% [markdown]
#  FOR V GENE MULTIPLICITY AND NUCLEOTIDE MULTIPLICITY

# %%
get_vnucl = V_nucl(data)
v_nucl = get_vnucl.make_vnucl()

# %%
v_nucl
# Out:
#                   aaSeqCDR3  V_mult  Nucl_mult
# 0        CARATAVVRGIINHFDYW       1          1
# 1            CARDPRGVLRGPDW       1          1
# 2       CARLNMVRGELWGYHFDYW       2          6
# 3      CARERIVPADRLYYYGMDVW       1          1
# 4          CLCLLTTIPERWFDPW       1          1
# ..                      ...     ...        ...
# 287  CAREEGSLRLGELSSYFGMDVW       1          1
# 288       CAHHRHVTTYHNWFDPW       1          1
# 289      CAREYGASYYYHYGMDVW       1          1
# 290   CAKDFYESRGYYREGDAFDIW       1          1
# 291          CARDVSIGVGADYW       1          1
#
# [292 rows x 3 columns]

# %% [markdown]
# EXPORT THE RESULTS

# %%
df_read.to_csv("output/df_read_test.tsv",sep="\t",index=False)
